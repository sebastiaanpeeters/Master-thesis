# %%
import xml.etree.ElementTree as ET
import pandas as pd

def parse_xml_to_dataframe(xml_file_path):
    # Parse the XML file
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # List to hold all recordings data
    data = []

    # Iterate over each speaker in the corpus
    for speaker in root.findall('speaker'):
        speaker_id = speaker.get('id')
        speaker_age = speaker.get('age')
        speaker_gender = speaker.get('gender')

        # Iterate over each recording for the current speaker
        for recording in speaker.findall('recording'):
            audio = recording.get('audio')
            md5sum = recording.get('md5sum')
            duration = recording.get('duration')
            pdp_score = recording.get('pdp_score')

            # Extract the transcription from the orth tag
            orth = recording.find('orth').text

            # Append the recording data to the list
            data.append({
                'speaker_id': speaker_id,
                'speaker_age': speaker_age,
                'speaker_gender': speaker_gender,
                'audio': audio,
                'md5sum': md5sum,
                'duration': duration,
                'pdp_score': pdp_score,
                'transcription': orth
            })

    # Create a DataFrame from the data list
    df = pd.DataFrame(data)
    return df

# %%
xml_file_path = 'nchlt_afr.trn.xml'
df = parse_xml_to_dataframe(xml_file_path)
print(df)
# Out:
#       speaker_id speaker_age speaker_gender  \
# 0            001          19           male
# 1            001          19           male
# 2            001          19           male
# 3            001          19           male
# 4            001          19           male
# ...          ...         ...            ...
# 63126        202          20         female
# 63127        202          20         female
# 63128        202          20         female
# 63129        202          20         female
# 63130        202          20         female
#
#                                              audio  \
# 0      nchlt_afr/audio/001/nchlt_afr_001m_0003.wav
# 1      nchlt_afr/audio/001/nchlt_afr_001m_0004.wav
# 2      nchlt_afr/audio/001/nchlt_afr_001m_0006.wav
# 3      nchlt_afr/audio/001/nchlt_afr_001m_0008.wav
# 4      nchlt_afr/audio/001/nchlt_afr_001m_0010.wav
# ...                                            ...
# 63126  nchlt_afr/audio/202/nchlt_afr_202f_0644.wav
# 63127  nchlt_afr/audio/202/nchlt_afr_202f_0646.wav
# 63128  nchlt_afr/audio/202/nchlt_afr_202f_0647.wav
# 63129  nchlt_afr/audio/202/nchlt_afr_202f_0648.wav
# 63130  nchlt_afr/audio/202/nchlt_afr_202f_0649.wav
#
#                                  md5sum duration pdp_score  \
# 0      2cc592cfd516e696357efd021e9226e7     3.96   -0.7900
# 1      8f9737571c066560f5b4605e3ed3b3ba     2.64   -0.6827
# 2      655a6c519ac261de5eb17b79e32156a0     5.04   -0.8597
# 3      daa046ae16623dddd3639d05e6266a04     3.24   -0.5397
# 4      13c56f34abe99b51c4350b28f1309864     5.88   -0.7039
# ...                                 ...      ...       ...
# 63126  5ae0888d887fb2f3fb095709f3c48dd2     1.92   -0.4995
# 63127  5bc149ee2873f2c27262f71a9d07cb28     1.56   -0.4720
# 63128  9915c42e2fec211de17add09822ae2d0     2.40   -0.7205
# 63129  5632966acbb496beb344de0cf6554b90     2.28   -0.4290
# 63130  b058af0f91afc7da8fb6ef7a910743b3     1.92   -0.8679
#
#                                transcription
# 0        registrasiesertifikaat uitreik mits
# 1                          dienste ten beste
# 2           sibw standaard inkomstebelasting
# 3                 vernaamste dienste verskaf
# 4      voorbedryfsuitgawes ingevolge artikel
# ...                                      ...
# 63126                     nog nooit spesiale
# 63127                              so ver as
# 63128                 nooit ooit duimgooiers
# 63129                enigste eerbare optrede
# 63130             heeltemal vertroulik gehou
#
# [63131 rows x 8 columns]

# %%
df.head(10)
# Out:
#   speaker_id speaker_age speaker_gender  \
# 0        001          19           male
# 1        001          19           male
# 2        001          19           male
# 3        001          19           male
# 4        001          19           male
# 5        001          19           male
# 6        001          19           male
# 7        001          19           male
# 8        001          19           male
# 9        001          19           male
#
#                                          audio  \
# 0  nchlt_afr/audio/001/nchlt_afr_001m_0003.wav
# 1  nchlt_afr/audio/001/nchlt_afr_001m_0004.wav
# 2  nchlt_afr/audio/001/nchlt_afr_001m_0006.wav
# 3  nchlt_afr/audio/001/nchlt_afr_001m_0008.wav
# 4  nchlt_afr/audio/001/nchlt_afr_001m_0010.wav
# 5  nchlt_afr/audio/001/nchlt_afr_001m_0017.wav
# 6  nchlt_afr/audio/001/nchlt_afr_001m_0020.wav
# 7  nchlt_afr/audio/001/nchlt_afr_001m_0024.wav
# 8  nchlt_afr/audio/001/nchlt_afr_001m_0026.wav
# 9  nchlt_afr/audio/001/nchlt_afr_001m_0028.wav
#
#                              md5sum duration pdp_score  \
# 0  2cc592cfd516e696357efd021e9226e7     3.96   -0.7900
# 1  8f9737571c066560f5b4605e3ed3b3ba     2.64   -0.6827
# 2  655a6c519ac261de5eb17b79e32156a0     5.04   -0.8597
# 3  daa046ae16623dddd3639d05e6266a04     3.24   -0.5397
# 4  13c56f34abe99b51c4350b28f1309864     5.88   -0.7039
# 5  f884ac03fb206ad7efef4476c4fdb2d9     2.40   -0.9158
# 6  75300f51ffb1892f68c4c19026190fdf     3.60   -0.8662
# 7  8749dcaa3c7483a539f02538f2e0929f     3.00   -0.8348
# 8  1845f21a852cf56393083d2189174fc4     3.48   -0.9104
# 9  011e0f11570147f574a4cdd41491a8af     2.28   -0.7673
#
#                            transcription
# 0    registrasiesertifikaat uitreik mits
# 1                      dienste ten beste
# 2       sibw standaard inkomstebelasting
# 3             vernaamste dienste verskaf
# 4  voorbedryfsuitgawes ingevolge artikel
# 5                   ek daarmee moontlike
# 6          finansiële jaarverslag voorlê
# 7               kinders jaarliks getoets
# 8       opportunistiese infeksies intree
# 9                 plaaslike hospitale sê

# %%
df.shape
# Out:
# (63131, 8)

# %%
df['duration'] = df['duration'].astype(float)

# %%
df['duration'].sum()/3600
# Out:
# 53.7031

# %%
xml_file_path = 'nchlt_afr.tst.xml'
df_test = parse_xml_to_dataframe(xml_file_path)
print(df_test.shape)
df_test.head(10)
# Out:
# (3002, 8)
#   speaker_id speaker_age speaker_gender  \
# 0        500          19           male
# 1        500          19           male
# 2        500          19           male
# 3        500          19           male
# 4        500          19           male
# 5        500          19           male
# 6        500          19           male
# 7        500          19           male
# 8        500          19           male
# 9        500          19           male
#
#                                          audio  \
# 0  nchlt_afr/audio/500/nchlt_afr_500m_0004.wav
# 1  nchlt_afr/audio/500/nchlt_afr_500m_0009.wav
# 2  nchlt_afr/audio/500/nchlt_afr_500m_0016.wav
# 3  nchlt_afr/audio/500/nchlt_afr_500m_0017.wav
# 4  nchlt_afr/audio/500/nchlt_afr_500m_0018.wav
# 5  nchlt_afr/audio/500/nchlt_afr_500m_0019.wav
# 6  nchlt_afr/audio/500/nchlt_afr_500m_0021.wav
# 7  nchlt_afr/audio/500/nchlt_afr_500m_0022.wav
# 8  nchlt_afr/audio/500/nchlt_afr_500m_0023.wav
# 9  nchlt_afr/audio/500/nchlt_afr_500m_0024.wav
#
#                              md5sum duration pdp_score  \
# 0  af3bbad361866af20c31022f27242d46     2.16   -0.2015
# 1  5b0f18dc5dcee2c587a56cf23db3c8d1     4.08   -0.9231
# 2  7c8f0186c32896397a51c0e584a20005     3.84   -0.8298
# 3  b4a2ac8e473935a687e78b74da7ba8fa     3.48   -0.4785
# 4  b4ffa3b0f02ac5c0c61b11eadc1693b5     1.68   -0.2487
# 5  d1d73ae8eaa59da9358e9617ba0bf017     2.64   -0.4007
# 6  60cf24f468a558f823d2cd202d01bd46     3.12   -0.2102
# 7  b3a64427c2ce52b21dfe40e19662db20     3.48   -0.7908
# 8  02fdac7d6fe568337ec3c0d647e663df     2.64   -0.4089
# 9  a0fd03249ab072f1a288feb97e7324a7     3.12   -0.5097
#
#                              transcription
# 0                            toerismewette
# 1  voorwaardelike dranklisensie [s] toeken
# 2            afal bestuursplan werksessies
# 3                  vuurwapen behoorlik weg
# 4                                  kultuur
# 5                byvoeglike naamwoord plus
# 6                   petisies aanlyn indien
# 7                 jong beroepslui meesters
# 8                         gebeur indien ek
# 9                  volgens sekere kriteria

# %%
df_test['duration'] = df_test['duration'].astype(float)
df_test['duration'].sum()/3600
# Out:
# 2.6647

# %%
df_test.speaker_id.unique()
# Out:
# array(['500', '501', '502', '503', '504', '505', '506', '507'],
#       dtype=object)

# %% [markdown]
# Take a sample from the train data to set aside as a validation split, and keep the remaining data as the training set.

# %%
df_val = df.sample(3000, random_state=42)

# %%
df_val['duration'].sum()/3600
# Out:
# 2.5568000000000004

# %%
#Create a train set with those values not in the validation set.
mask = ~df.set_index(['audio']).index.isin(df_val.set_index(['audio']).index)

# Use the mask to filter df
df_train = df[mask].reset_index(drop=True)

# %%
df_train.shape
# Out:
# (60131, 8)

# %%
df_train.head(10)
# Out:
#   speaker_id speaker_age speaker_gender  \
# 0        001          19           male
# 1        001          19           male
# 2        001          19           male
# 3        001          19           male
# 4        001          19           male
# 5        001          19           male
# 6        001          19           male
# 7        001          19           male
# 8        001          19           male
# 9        001          19           male
#
#                                          audio  \
# 0  nchlt_afr/audio/001/nchlt_afr_001m_0003.wav
# 1  nchlt_afr/audio/001/nchlt_afr_001m_0004.wav
# 2  nchlt_afr/audio/001/nchlt_afr_001m_0006.wav
# 3  nchlt_afr/audio/001/nchlt_afr_001m_0008.wav
# 4  nchlt_afr/audio/001/nchlt_afr_001m_0010.wav
# 5  nchlt_afr/audio/001/nchlt_afr_001m_0017.wav
# 6  nchlt_afr/audio/001/nchlt_afr_001m_0020.wav
# 7  nchlt_afr/audio/001/nchlt_afr_001m_0024.wav
# 8  nchlt_afr/audio/001/nchlt_afr_001m_0026.wav
# 9  nchlt_afr/audio/001/nchlt_afr_001m_0028.wav
#
#                              md5sum  duration pdp_score  \
# 0  2cc592cfd516e696357efd021e9226e7      3.96   -0.7900
# 1  8f9737571c066560f5b4605e3ed3b3ba      2.64   -0.6827
# 2  655a6c519ac261de5eb17b79e32156a0      5.04   -0.8597
# 3  daa046ae16623dddd3639d05e6266a04      3.24   -0.5397
# 4  13c56f34abe99b51c4350b28f1309864      5.88   -0.7039
# 5  f884ac03fb206ad7efef4476c4fdb2d9      2.40   -0.9158
# 6  75300f51ffb1892f68c4c19026190fdf      3.60   -0.8662
# 7  8749dcaa3c7483a539f02538f2e0929f      3.00   -0.8348
# 8  1845f21a852cf56393083d2189174fc4      3.48   -0.9104
# 9  011e0f11570147f574a4cdd41491a8af      2.28   -0.7673
#
#                            transcription
# 0    registrasiesertifikaat uitreik mits
# 1                      dienste ten beste
# 2       sibw standaard inkomstebelasting
# 3             vernaamste dienste verskaf
# 4  voorbedryfsuitgawes ingevolge artikel
# 5                   ek daarmee moontlike
# 6          finansiële jaarverslag voorlê
# 7               kinders jaarliks getoets
# 8       opportunistiese infeksies intree
# 9                 plaaslike hospitale sê

# %%
from datasets import Dataset, DatasetDict
def create_dataset(filepaths, transcriptions):
    dataset_dict = {
        "file": filepaths,
        "text": transcriptions,
        # Add other fields as necessary, e.g., "text": [text1, text2, ...]
    }
    return dataset_dict

# %%
# Create datasets
train_dataset = Dataset.from_dict(create_dataset(df_train['audio'], df_train['transcription']))
val_dataset = Dataset.from_dict(create_dataset(df_val['audio'], df_val['transcription']))
test_dataset = Dataset.from_dict(create_dataset(df_test['audio'], df_test['transcription']))

# Create a DatasetDict
dataset_dict = DatasetDict({
    "train": train_dataset,
    "validation": val_dataset,
    "test": test_dataset
})

# %%
dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'text'],
#         num_rows: 60131
#     })
#     validation: Dataset({
#         features: ['file', 'text'],
#         num_rows: 3000
#     })
#     test: Dataset({
#         features: ['file', 'text'],
#         num_rows: 3002
#     })
# })

# %%
# Save the dataset to disk
dataset_dict.save_to_disk("dataset_afr_only")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/60131 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/3002 [00:00<?, ? examples/s]
